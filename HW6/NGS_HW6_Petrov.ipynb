# %% [markdown]
# # 1. Сборка длинных ридов

# %% [markdown]
# `flye --pacbio-raw pacbio_*x.fq.gz --out-dir pacbio_*x`

# %%
from IPython.display import Image

# %%
Image("quast_pacbio_1.png")

# %% [markdown]
# # 2. Сборка коротких ридов

# %% [markdown]
# `./spades.py -1 illumina.100x.1.fq.gz -2 illumina.100x.2.fq.gz -o illumina`

# %%
Image("quast_ill_1.png")

# %% [markdown]
# # 3. Гибридная сборка

# %% [markdown]
# `./spades.py -1 illumina.100x.1.fq.gz -2 illumina.100x.2.fq.gz --pacbio pacbio_*x.fq.gz -o hybrid_*`

# %%
Image("quast_hyb_1.png")

# %% [markdown]
# # 4. Сравнение сборок

# %%
Image("quast_cum_len.png")

# %%
Image("quast_gc.png")

# %% [markdown]
# Почти все сборки покрывают 99+ % генома, за исключением сборки pac_10 и иллюмины.
#
# Для сборок по длинным ридам характерно наличие мисассемблов, которые хоть и уменьшаются с увеличением покрытия, но не равны нулю, чего не скажешь о коротких ридах иллюмины.
#
# Для гибридных сборок количество мисмэтчей больше, чем для иллюмины или pacbio 20x и больше.
#
# По длине все сборки выходят на один и тот же уровень.
#
# Уровень GC контента также примерно одинаков для всех сборок.
#
# В целом, все сборки схожи по общему качеству, сильно выделяется только первая сборка pacbio_10x

# %%
Image('contig_alignment.png')

# %% [markdown]
# В сборках PacBio и гибридных сборках присутствуют мисассемблы в одинаковых местах, что может быть вызвано структурными перестройками в отсеквенированных геномах
